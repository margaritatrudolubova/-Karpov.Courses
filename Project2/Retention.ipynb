# %% [markdown]
# Задание 1.
#
# Retention – один из самых важных показателей в компании. Ваша задача – написать функцию, которая будет считать retention игроков (по дням от даты регистрации игрока). Функция должна быть написана на python. В ходе решения можно тестировать работу функции как на полном датасете, так и на части (сэмпле) данных.

# %%
import pandas as pd

import numpy as np

import seaborn as sns
# %matplotlib inline

import matplotlib.pyplot as plt

import datetime

from matplotlib.ticker import FuncFormatter

import matplotlib.ticker as ticker

from scipy import stats

from tqdm.auto import tqdm

from scipy.stats import norm

from scipy.stats import mannwhitneyu

import statsmodels.api as sms

# %%
#Загрузим все наши таблицы и посмотрим на их содержание

# %%
#данные о времени регистрации
df_reg= pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-m-trudoljubova/shared/problem1-reg_data.csv', sep=';')
df_reg.head()
# Out:
#       reg_ts  uid
# 0  911382223    1
# 1  932683089    2
# 2  947802447    3
# 3  959523541    4
# 4  969103313    5

# %%
#данные о времени захода пользователей в игру
df_auth= pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-m-trudoljubova/shared/problem1-auth_data.csv', sep= ';')
df_auth.head()
# Out:
#      auth_ts  uid
# 0  911382223    1
# 1  932683089    2
# 2  932921206    2
# 3  933393015    2
# 4  933875379    2

# %%
#Напишем функцию для объединения датафреймов в общий 

def df_consolidation():
    
    df_reg.reg_ts = df_reg.reg_ts.apply(lambda x: datetime.datetime.fromtimestamp(x).date())
    df_auth.auth_ts = df_auth.auth_ts.apply(lambda x: datetime.datetime.fromtimestamp(x).date())
  
    ar_df = df_auth.merge(df_reg, how='left', on='uid')
    
    return ar_df

# %%
ar_df = df_consolidation()

# %%
#Посмотрим на наши данные
ar_df.head()
# Out:
#       auth_ts  uid      reg_ts
# 0  1998-11-18    1  1998-11-18
# 1  1999-07-23    2  1999-07-23
# 2  1999-07-25    2  1999-07-23
# 3  1999-07-31    2  1999-07-23
# 4  1999-08-05    2  1999-07-23

# %%
ar_df.dtypes
# Out:
# auth_ts    object
# uid         int64
# reg_ts     object
# dtype: object

# %%
ar_df.describe()
# Out:
#                 uid
# count  9.601013e+06
# mean   3.347198e+05
# std    2.832669e+05
# min    1.000000e+00
# 25%    9.599700e+04
# 50%    2.579210e+05
# 75%    5.190250e+05
# max    1.110622e+06

# %%
#Напишем функцию для расчета retention, где 
# df - данные для расчёта, 
# Nlast_days - количество последних дней, за которые мы посмотрим retention (для наглядности возьмем 30 дней)

# %%
def retention(df, Nlast_days=30):

    last_day = df.reg_ts.max() #Определим последний день в данных
    start_day = last_day - pd.offsets.Day(Nlast_days) #Определим день, с которого начнем отсчет retention
    
#Обработаем наши данные для работы с когортами и создадим Pivot table, где дни-когорты будут индексы, а n_day в колонках.
    cohorts = df.query('reg_ts > @start_day').rename(columns={'reg_ts': 'reg_day_', 'auth_ts': 'auth_day'})
    cohorts['n_day'] = (cohorts['auth_day'] - cohorts['reg_day_']).dt.days
    cohorts['reg_day'] = cohorts['reg_day_'].apply(lambda x: x.strftime('%Y-%m-%d'))
    cohorts = cohorts\
                        .groupby(['reg_day', 'auth_day', 'n_day'], as_index=False)\
                        .agg({'uid': pd.Series.nunique})\
                        .rename(columns={'uid': 'total_users'})\
                        .pivot(index='reg_day', columns='n_day', values='total_users')

    cohort_group_size = cohorts[0] #Определяем размеры каждой когорты

    user_retention = cohorts.divide(cohort_group_size, axis=0) #Разделим каждодневное количество пользователей для ккаждой когорты на размер когорты

    
#Теперь создадим функцию для нашей таблицы retention
    def make_style(df):
        return (df
                    .style
                    .set_caption('User retention cohort')
                    .set_table_styles([{
                                    'selector': 'caption',
                                    'props': [
                                        ('color', 'black'),
                                        ('font-size', '25px'),
                                        ('text-align','center')
                                    ]
                                }])) #Подпись таблицы
                
    return make_style(user_retention)

# %%
#Построим таблицу для нашего retention
retention(ar_df, 18)
# Out:
# <style  type="text/css" >
#     #T_3299b8ae_6b63_11ed_bdbb_96000040dfb6 caption {
#           color: black;
#           font-size: 25px;
#           text-align: center;
#     }</style><table id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6" ><caption>User retention cohort</caption><thead>    <tr>        <th class="index_name level0" >n_day</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>        <th class="col_heading level0 col9" >9</th>        <th class="col_heading level0 col10" >10</th>        <th class="col_heading level0 col11" >11</th>        <th class="col_heading level0 col12" >12</th>        <th class="col_heading level0 col13" >13</th>        <th class="col_heading level0 col14" >14</th>        <th class="col_heading level0 col15" >15</th>        <th class="col_heading level0 col16" >16</th>        <th class="col_heading level0 col17" >17</th>    </tr>    <tr>        <th class="index_name level0" >reg_day</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6level0_row0" class="row_heading level0 row0" >2020-09-06</th>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col1" class="data row0 col1" >0.035044</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col2" class="data row0 col2" >0.043179</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col3" class="data row0 col3" >0.051314</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col4" class="data row0 col4" >0.058198</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col5" class="data row0 col5" >0.058198</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col6" class="data row0 col6" >0.069462</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col7" class="data row0 col7" >0.064456</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col8" class="data row0 col8" >0.056320</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col9" class="data row0 col9" >0.055695</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col10" class="data row0 col10" >0.055069</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col11" class="data row0 col11" >0.055695</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col12" class="data row0 col12" >0.046308</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col13" class="data row0 col13" >0.051314</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col14" class="data row0 col14" >0.058198</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col15" class="data row0 col15" >0.050688</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col16" class="data row0 col16" >0.050688</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row0_col17" class="data row0 col17" >0.031289</td>
#             </tr>
#             <tr>
#                         <th id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6level0_row1" class="row_heading level0 row1" >2020-09-07</th>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col0" class="data row1 col0" >1.000000</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col1" class="data row1 col1" >0.027483</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col2" class="data row1 col2" >0.041224</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col3" class="data row1 col3" >0.054966</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col4" class="data row1 col4" >0.049969</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col5" class="data row1 col5" >0.066833</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col6" class="data row1 col6" >0.063710</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col7" class="data row1 col7" >0.057464</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col8" class="data row1 col8" >0.041849</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col9" class="data row1 col9" >0.046846</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col10" class="data row1 col10" >0.056215</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col11" class="data row1 col11" >0.059963</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col12" class="data row1 col12" >0.051218</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col13" class="data row1 col13" >0.043098</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col14" class="data row1 col14" >0.045597</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col15" class="data row1 col15" >0.047470</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col16" class="data row1 col16" >0.039975</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row1_col17" class="data row1 col17" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6level0_row2" class="row_heading level0 row2" >2020-09-08</th>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row2_col0" class="data row2 col0" >1.000000</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row2_col1" class="data row2 col1" >0.019327</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row2_col2" class="data row2 col2" >0.035536</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row2_col3" class="data row2 col3" >0.034289</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row2_col4" class="data row2 col4" >0.058603</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row2_col5" class="data row2 col5" >0.070449</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row2_col6" class="data row2 col6" >0.072319</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row2_col7" class="data row2 col7" >0.066708</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row2_col8" class="data row2 col8" >0.049875</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row2_col9" class="data row2 col9" >0.056110</td>
#                         <td id="T_3299b8ae_6b63_11ed_bdbb_96000040dfb6row2_col1

# %%
#Для удобства переведем значения в проценты и раскрасим в более красивую таблицу:)
retention(ar_df, 18).format("{:.2%}", na_rep="").background_gradient(cmap='PuBu')
# Out:
# <style  type="text/css" >
#     #T_3c74aabe_6b63_11ed_bdbb_96000040dfb6 caption {
#           color: black;
#           font-size: 25px;
#           text-align: center;
#     }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col16,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col3,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col15,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row3_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row3_col10,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row3_col14,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row3_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row4_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row4_col13,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row4_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row5_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row5_col12,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row5_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row6_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row6_col4,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row6_col11,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row6_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row7_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row7_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row8_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row8_col9,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row8_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row9_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row9_col8,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row9_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row10_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row10_col7,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row10_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row11_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row11_col6,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row11_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row12_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row12_col5,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row12_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row13_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row13_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row14_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row14_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row15_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row15_col2,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row15_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row16_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row16_col1,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row16_col17,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row17_col0,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row17_col17{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col1,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col8,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col14,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col15,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col16,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col3,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col5,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col9,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col10,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col12,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col13,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row3_col4,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row5_col11,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row7_col2,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row8_col7,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row10_col6{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col2{
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col3,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col14{
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col4{
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col5{
#             background-color:  #69a5cc;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col6{
#             background-color:  #2a88bc;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col7,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col5{
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col9{
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col10,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row6_col2{
#             background-color:  #187cb6;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col11,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row12_col2{
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col12{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row0_col13{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col1{
#             background-color:  #2c89bd;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col2,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row7_col9,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row10_col2{
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col4,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col13{
#             background-color:  #91b5d6;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col6{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col7,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row3_col8,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row8_col6{
#             background-color:  #3d93c2;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col8{
#             background-color:  #7bacd1;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col9{
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col10{
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col11{
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col12{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col14,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row4_col11{
#             background-color:  #509ac6;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row1_col15,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col8{
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col1{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col2,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row6_col3{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col4{
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col6,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row6_col9{
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row2_col7,#T_3c74aabe_6b63_11ed_bdbb_96000040dfb6row5_col4{
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }#T_3c7
